# %%
# データ分析・操作用ライブラリ
import numpy as np
import pandas as pd
from collections import Counter
import itertools

# %%
# !ls
# Out:
# sample_data  train.csv

# %%
# CSVの読み込み
wikiData = pd.read_csv("train.csv", encoding="utf-8",engine="python" )

# 読み込みデータの表示
wikiData.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-23-429e12940a4d> in <module>()
# ----> 1 wikiData = pd.read_csv("train.csv", encoding="utf-8",engine="python" )
#       2
#       3 # 読み込みデータの表示
#       4 wikiData.head()
#
# ...

# %%
import codecs


# CSVの読み込み
with codecs.open('train.csv', 'r', 'utf-8', "ignore") as f:
    wikiData = pd.read_csv(f,engine="python")

# 読み込みデータの表示
wikiData.head()
# Out:
#                                          text,target
# 0   h[Et[hEJpj[  h[Et[hEJpj[iDole Food Company In...
# 1   샖uq   샖uqi݂Ȃ݂ڂ傤j́AȖ،ߐ{ɖ{u_ocƁB4̖qocĂB  όɗ͂ĂA...
# 2   ␣q  ␣qi킹ڂ傤j́A{̕␣SΒɂqłB  Β̃V{\OíjƂ镶ȏ́uq̒ṽfƂȂ...
# 3  " NM  NMЁi炬A""KURAGI Co.Ltd."" j́AOd𒆐SɁu_ƉvȂǂ̓...
# 4  " nbs[lt@[  Ѓnbs[lt@[i""""j́AkCY͌SY͒ɂ鋣niTubhj̃...

# %%
# !python --version
# Out:
# Python 3.6.8

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b4fd0181-6dad-465f-b320-24aa51e2513a" name="files[]" multiple disabled />
#      <output id="result-b4fd0181-6dad-465f-b320-24aa51e2513a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train (1).csv

# %%
with codecs.open("train.csv", "r", "utf-8","ignore") as f:
    Wikidata = pd.read_table(f, delimiter=",", engine="python")
Wikidata.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#                                          text,target
# 0   h[Et[hEJpj[  h[Et[hEJpj[iDole Food Company In...
# 1   샖uq   샖uqi݂Ȃ݂ڂ傤j́AȖ،ߐ{ɖ{u_ocƁB4̖qocĂB  όɗ͂ĂA...
# 2   ␣q  ␣qi킹ڂ傤j́A{̕␣SΒɂqłB  Β̃V{\OíjƂ镶ȏ́uq̒ṽfƂȂ...
# 3  " NM  NMЁi炬A""KURAGI Co.Ltd."" j́AOd𒆐SɁu_ƉvȂǂ̓...
# 4  " nbs[lt@[  Ѓnbs[lt@[i""""j́AkCY͌SY͒ɂ鋣niTubhj̃...

# %%
# CSVの読み込み
wikiData = pd.read_csv("train.csv", encoding="utf-8")

# 読み込みデータの表示
wikiData.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-29-17bd2c45617e> in <module>()
# ----> 1 wikiData = pd.read_csv("train.csv", encoding="utf-8")
#       2
#       3 # 読み込みデータの表示
#       4 wikiData.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
from google.colab import files
files.download("Remove Unnessary Word.ipynb")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-6edccd852271> in <module>()
#       1 from google.colab import files
# ----> 2 files.download("Remove Unnessary Word.ipynb")
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     142       raise OSError(msg)
#     143     else:
# --> 144       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     145
#     146   started = _threading.Event()
#
# FileNotFoundError: Cannot find file: Remove Unnessary Word.ipynb
